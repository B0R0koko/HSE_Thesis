# %%
import pandas as pd
import os

os.chdir("..")

# %%
df = pd.read_csv("collection/merged_data.csv")

# %%
df
# Out:
#                               company_name  world_rank_2022  world_rank_2021  \
# 0                   LONGFOR GROUP HOLDINGS              677            775.0
# 1                                    BAIDU              354            346.0
# 2                 GREAT WALL MOTOR COMPANY              350            224.0
# 3     CHONGQING ZHIFEI BIOLOGICAL PRODUCTS              729            469.0
# 4                           LUZHOU LAOJIAO              346            507.0
# ...                                    ...              ...              ...
# 1996                      SAMSARA NETWORKS             2562           2562.0
# 1997                    COLFAX CORPORATION             2528           2557.0
# 1998                      ONEMAIN HOLDINGS             2543           2421.0
# 1999       UNITED STATES STEEL CORPORATION             2546           2542.0
# 2000                 PROSPERITY BANCSHARES             2491           2784.0
#
# ...
